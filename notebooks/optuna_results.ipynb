# %% [markdown]
# # Optuna Results
# The following results are from optuna hyperparameter optimizations

# %%
import pandas as pd

# %%
df = pd.read_csv('optuna_results_2.csv')
df
# Out:
#    number       value  params_batch_size  params_buffer_size  \
# 0       0 -100.228227                 64              200000
# 1       1  150.407259                 64              100000
# 2       2 -229.821695                 64              200000
# 3       3 -152.973371                 64              200000
# 4       4 -180.518918                 32              200000
# 5       5 -198.490605                 32              200000
# 6       6  -28.017050                 64              200000
# 7       7 -145.246118                 32              200000
# 8       8 -217.282379                 32              100000
# 9       9 -116.885970                 64              100000
#
#    params_decay_rate  params_exploration_final_eps  \
# 0           0.698763                      0.039180
# 1           0.284802                      0.052002
# 2           0.666218                      0.025636
# 3           0.451621                      0.083141
# ...

# %%
df.to_markdown('optuna_results_DuelingDoubleDQN_LnLr_25_Actions_4_states.md')
