# %% [markdown]
# # Optuna Results
# The following results are from optuna hyperparameter optimizations

# %%
import pandas as pd

# %%
df = pd.read_csv('./notebooks/optuna_results.csv')
df
# Out:
#     number       value  params_batch_size  params_buffer_size  \
# 0        0  -95.565657                 64              250000
# 1        1 -170.000000                 64              250000
# 2        2 -243.204417                 32              450000
# 3        3 -411.287479                 64              100000
# 4        4 -372.094128                 64              400000
# 5        5 -170.000000                 32              200000
# 6        6 -480.000000                 64               50000
# 7        7  -65.360468                 32              200000
# 8        8 -296.817662                 64              200000
# 9        9 -146.599656                 32              100000
# 10      10  -81.554319                 32              350000
# 11      11 -453.461096                 32              350000
# 12      12 -183.299861                 32              350000
# 13      13 -331.313889                 32              500000
# ...

# %%
df.to_markdown('./notebooks/optuna_results_24_actions.md')
